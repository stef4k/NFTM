# %% [markdown]
# ## Weight and Biases Dashboard
# Grid search of parameters using weight and biases:

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

import os
os.chdir("/content/drive/MyDrive/NFTM")
# Out:
# Mounted at /content/drive

# %%
# !pip install lpips
# !pip install torchmetrics[image]
# !pip install wandb
# !pip install weave
# Out:
# Requirement already satisfied: lpips in /usr/local/lib/python3.12/dist-packages (0.1.4)
# Requirement already satisfied: torch>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from lpips) (2.8.0+cu126)
# Requirement already satisfied: torchvision>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from lpips) (0.23.0+cu126)
# Requirement already satisfied: numpy>=1.14.3 in /usr/local/lib/python3.12/dist-packages (from lpips) (2.0.2)
# Requirement already satisfied: scipy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from lpips) (1.16.3)
# Requirement already satisfied: tqdm>=4.28.1 in /usr/local/lib/python3.12/dist-packages (from lpips) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.0->lpips) (3.4.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision>=0.2.1->lpips) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=0.4.0->lpips) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=0.4.0->lpips) (3.0.3)
# Requirement already satisfied: torchmetrics[image] in /usr/local/lib/python3.12/dist-packages (1.8.2)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.12/dist-packages (from torchmetrics[image]) (2.0.2)
# Requirement already satisfied: packaging>17.1 in /usr/local/lib/python3.12/dist-packages (from torchmetrics[image]) (25.0)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from torchmetrics[image]) (2.8.0+cu126)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from torchmetrics[image]) (0.15.2)
# Requirement already satisfied: torch-fidelity<=0.4.0 in /usr/local/lib/python3.12/dist-packages (from torchmetrics[image]) (0.3.0)
# Requirement already satisfied: torchvision>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from torchmetrics[image]) (0.23.0+cu126)
# Requirement already satisfied: scipy>1.0.0 in /usr/local/lib/python3.12/dist-packages (from torchmetrics[image]) (1.16.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from lightning-utilities>=0.8.0->torchmetrics[image]) (80.9.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from lightning-utilities>=0.8.0->torchmetrics[image]) (4.15.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics[image]) (3.20.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics[image]) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics[image]) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics[image]) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics[image]) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics[image]) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics[image]) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics[image]) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics[image]) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics[image]) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics[image]) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics[image]) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics[image]) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics[image]) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics[image]) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics[image]) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics[image]) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics[image]) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics[image]) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics[image]) (3.4.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from torch-fidelity<=0.4.0->torchmetrics[image]) (11.3.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from torch-fidelity<=0.4.0->torchmetrics[image]) (4.67.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->torchmetrics[image]) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->torchmetrics[image]) (3.0.3)
# Requirement already satisfied: wandb in /usr/local/lib/python3.12/dist-packages (0.22.2)
# Requirement already satisfied: click>=8.0.1 in /usr/local/lib/python3.12/dist-packages (from wandb) (8.3.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (3.1.45)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from wandb) (25.0)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb) (4.5.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (5.29.5)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.12/dist-packages (from wandb) (2.11.10)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from wandb) (6.0.3)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (2.32.4)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb) (2.42.1)
# Requirement already satisfied: typing-extensions<5,>=4.8 in /usr/local/lib/python3.12/dist-packages (from wandb) (4.15.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb) (2025.10.5)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.2)
# Requirement already satisfied: weave in /usr/local/lib/python3.12/dist-packages (0.52.14)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from weave) (8.3.0)
# Requirement already satisfied: diskcache==5.6.3 in /usr/local/lib/python3.12/dist-packages (from weave) (5.6.3)
# Requirement already satisfied: eval-type-backport in /usr/local/lib/python3.12/dist-packages (from weave) (0.2.2)
# Requirement already satisfied: gql>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from gql[aiohttp,requests]>=3.0.0->weave) (4.0.0)
# Requirement already satisfied: jsonschema>=4.23.0 in /usr/local/lib/python3.12/dist-packages (from weave) (4.25.1)
# Requirement already satisfied: packaging>=21.0 in /usr/local/lib/python3.12/dist-packages (from weave) (25.0)
# Requirement already satisfied: polyfile-weave in /usr/local/lib/python3.12/dist-packages (from weave) (0.5.7)
# Requirement already satisfied: pydantic>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from weave) (2.11.10)
# Requirement already satisfied: sentry-sdk<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from weave) (2.42.1)
# Requirement already satisfied: tenacity!=8.4.0,>=8.3.0 in /usr/local/lib/python3.12/dist-packages (from weave) (8.5.0)
# Requirement already satisfied: wandb>=0.17.1 in /usr/local/lib/python3.12/dist-packages (from weave) (0.22.2)
# Requirement already satisfied: graphql-core<3.3,>=3.2 in /usr/local/lib/python3.12/dist-packages (from gql>=3.0.0->gql[aiohttp,requests]>=3.0.0->weave) (3.2.7)
# Requirement already satisfied: yarl<2.0,>=1.6 in /usr/local/lib/python3.12/dist-packages (from gql>=3.0.0->gql[aiohttp,requests]>=3.0.0->weave) (1.22.0)
# Requirement already satisfied: backoff<3.0,>=1.11.1 in /usr/local/lib/python3.12/dist-packages (from gql>=3.0.0->gql[aiohttp,requests]>=3.0.0->weave) (2.2.1)
# Requirement already satisfied: anyio<5,>=3.0 in /usr/local/lib/python3.12/dist-packages (from gql>=3.0.0->gql[aiohttp,requests]>=3.0.0->weave) (4.11.0)
# Requirement already satisfied: aiohttp<4,>=3.11.2 in /usr/local/lib/python3.12/dist-packages (from gql[aiohttp,requests]>=3.0.0->weave) (3.13.1)
# Requirement already satisfied: requests<3,>=2.26 in /usr/local/lib/python3.12/dist-packages (from gql[aiohttp,requests]>=3.0.0->weave) (2.32.4)
# Requirement already satisfied: requests_toolbelt<2,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from gql[aiohttp,requests]>=3.0.0->weave) (1.0.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.23.0->weave) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.23.0->weave) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.23.0->weave) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.23.0->weave) (0.28.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->weave) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->weave) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->weave) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->weave) (0.4.2)
# Requirement already satisfied: urllib3>=1.26.11 in /usr/local/lib/python3.12/dist-packages (from sentry-sdk<3.0.0,>=2.0.0->weave) (2.5.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from sentry-sdk<3.0.0,>=2.0.0->weave) (2025.10.5)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.17.1->weave) (3.1.45)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb>=0.17.1->weave) (4.5.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.17.1->weave) (5.29.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from wandb>=0.17.1->weave) (6.0.3)
# Requirement already satisfied: abnf~=2.2.0 in /usr/local/lib/python3.12/dist-packages (from polyfile-weave->weave) (2.2.0)
# Requirement already satisfied: chardet>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from polyfile-weave->weave) (5.2.0)
# Requirement already satisfied: cint>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from polyfile-weave->weave) (1.0.0)
# Requirement already satisfied: fickling>=0.0.8 in /usr/local/lib/python3.12/dist-packages (from polyfile-weave->weave) (0.1.4)
# Requirement already satisfied: graphviz>=0.20.1 in /usr/local/lib/python3.12/dist-packages (from polyfile-weave->weave) (0.21)
# Requirement already satisfied: intervaltree>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from polyfile-weave->weave) (3.1.0)
# Requirement already satisfied: jinja2>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from polyfile-weave->weave) (3.1.6)
# Requirement already satisfied: kaitaistruct~=0.10 in /usr/local/lib/python3.12/dist-packages (from polyfile-weave->weave) (0.11)
# Requirement already satisfied: networkx>=2.6.3 in /usr/local/lib/python3.12/dist-packages (from polyfile-weave->weave) (3.5)
# Requirement already satisfied: pdfminer.six<=20250506,>=20220524 in /usr/local/lib/python3.12/dist-packages (from polyfile-weave->weave) (20250506)
# Requirement already satisfied: Pillow>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from polyfile-weave->weave) (11.3.0)
# Requirement already satisfied: setuptools>=80.9.0 in /usr/local/lib/python3.12/dist-packages (from polyfile-weave->weave) (80.9.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.11.2->gql[aiohttp,requests]>=3.0.0->weave) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.11.2->gql[aiohttp,requests]>=3.0.0->weave) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.11.2->gql[aiohttp,requests]>=3.0.0->weave) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.11.2->gql[aiohttp,requests]>=3.0.0->weave) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.11.2->gql[aiohttp,requests]>=3.0.0->weave) (0.4.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.0->gql>=3.0.0->gql[aiohttp,requests]>=3.0.0->weave) (3.11)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.0->gql>=3.0.0->gql[aiohttp,requests]>=3.0.0->weave) (1.3.1)
# Requirement already satisfied: stdlib_list~=0.11.1 in /usr/local/lib/python3.12/dist-packages (from fickling>=0.0.8->polyfile-weave->weave) (0.11.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb>=0.17.1->weave) (4.0.12)
# Requirement already satisfied: sortedcontainers<3.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from intervaltree>=2.4.0->polyfile-weave->weave) (2.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=2.1.0->polyfile-weave->weave) (3.0.3)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer.six<=20250506,>=20220524->polyfile-weave->weave) (3.4.4)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer.six<=20250506,>=20220524->polyfile-weave->weave) (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=36.0.0->pdfminer.six<=20250506,>=20220524->polyfile-weave->weave) (2.0.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb>=0.17.1->weave) (5.0.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six<=20250506,>=20220524->polyfile-weave->weave) (2.23)

# %%
# !wandb login
# Out:
# wandb: Currently logged in as: stef4k (stef4k-centralesup-lec) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %%
import wandb
import random
import math
import itertools
import subprocess
# Out:
# 0.22.2

# %% [markdown]
# Now we can define the parameters and run the grid executions:

# %%
import itertools, wandb, sys
from image_inpainting import main

param_grid = {
    "img_size": [32],
    "K_train": [10],
    "K_eval": [20],
    "epochs": [5, 7],
    "controller": ["dense"],
}

for (img_size, k_train, k_eval, epochs, controller) in itertools.product(
    param_grid["img_size"],
    param_grid["K_train"],
    param_grid["K_eval"],
    param_grid["epochs"],
    param_grid["controller"]
):
    run = wandb.init(
        project="image_inpainting_notebook",
        config={
            "img_size": img_size,
            "K_train": k_train,
            "K_eval": k_eval,
            "epochs": epochs,
            "controller": controller,
        },
        reinit=True,
      settings=wandb.Settings(start_method="thread"),
        name=f"img{img_size}_ktrain{k_train}_keval{k_eval}_epochs{epochs}_{controller}",
    )

    # configure arguments (using CIFAR)
    sys.argv = [
        "image_inpainting.py",
        "--img_size", str(img_size),
        "--train_dataset", "cifar",
        "--benchmark", "cifar",
        "--K_train", str(k_train),
        "--K_eval", str(k_eval),
        "--epochs", str(epochs),
        "--controller", controller,
        "--save_metrics",
        "--use_wandb",
        "--save_dir", f"out/img{img_size}_{controller}",
        "--batch_size", "16"
    ]

    print(f"\n=== Running config: controller={controller}, K_train={k_train}, K_eval={k_eval}, epochs={epochs} ===\n")
    main()
    run.finish()
# Out:
# wandb: WARNING `start_method` is deprecated and will be removed in a future version of wandb. This setting is currently non-functional and safely ignored.
# wandb: Currently logged in as: stef4k (stef4k-centralesup-lec) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/drive/MyDrive/NFTM/wandb/run-20251102_203219-xjhikdc6</code>
# Syncing run <strong><a href='https://wandb.ai/stef4k-centralesup-lec/image_inpainting_notebook/runs/xjhikdc6' target="_blank">img32_ktrain10_keval20_epochs5_dense</a></strong> to <a href='https://wandb.ai/stef4k-centralesup-lec/image_inpainting_notebook' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/stef4k-centralesup-lec/image_inpainting_notebook' target="_blank">https://wandb.ai/stef4k-centralesup-lec/image_inpainting_notebook</a>
#  View run at <a href='https://wandb.ai/stef4k-centralesup-lec/image_inpainting_notebook/runs/xjhikdc6' target="_blank">https://wandb.ai/stef4k-centralesup-lec/image_inpainting_notebook/runs/xjhikdc6</a>
# === Running config: controller=dense, K_train=10, K_eval=20, epochs=5 ===
#
# [device] cuda | criterion=MSE
# [controller] dense | params=46375
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Loading model from: /usr/local/lib/python3.12/dist-packages/lpips/weights/v0.1/alex.pth
# [ep 01] β_train=0.280 K_train=5 | loss 0.1257 | train PSNR 15.28 dB | eval PSNR 1..20: 14.98, 15.35, 15.69, 16.01, 16.31 ... 18.88 | ctrl=dense | final SSIM 0.5615 | final LPIPS 0.0616
# [ep 02] β_train=0.310 K_train=6 | loss 0.1266 | train PSNR 15.25 dB | eval PSNR 1..20: 14.93, 15.26, 15.56, 15.83, 16.08 ... 17.72 | ctrl=dense | final SSIM 0.4312 | final LPIPS 0.0772
# [ep 03] β_train=0.340 K_train=7 | loss 0.1249 | train PSNR 15.31 dB | eval PSNR 1..20: 14.95, 15.27, 15.55, 15.79, 16.00 ... 16.95 | ctrl=dense | final SSIM 0.3770 | final LPIPS 0.0900
# [ep 04] β_train=0.370 K_train=8 | loss 0.1247 | train PSNR 15.32 dB | eval PSNR 1..20: 14.96, 15.29, 15.58, 15.83, 16.03 ... 16.66 | ctrl=dense | final SSIM 0.3546 | final LPIPS 0.0997
# [ep 05] β_train=0.400 K_train=9 | loss 0.1204 | train PSNR 15.48 dB | eval PSNR 1..20: 15.03, 15.41, 15.74, 16.03, 16.28 ... 17.17 | ctrl=dense | final SSIM 0.3938 | final LPIPS 0.0816
# [plot] saved step-wise psnr (eval) → out/img32_dense/psnr_curve.png
# [plot] saved step-wise ssim (eval) → out/img32_dense/ssim_curve.png
# [plot] saved step-wise lpips (eval) → out/img32_dense/lpips_curve.png
# [viz] saved per-epoch progression → out/img32_dense/final/progress_epoch_final.png
# [gif] saved reconstruction GIF (GT top row, recon bottom) → out/img32_dense/final/progress_epoch_final.gif
# [done] checkpoints and plots saved under: out/img32_dense | controller=dense
# /usr/local/lib/python3.12/dist-packages/torchmetrics/utilities/prints.py:43: UserWarning: Metric `Kernel Inception Distance` will save all extracted features in buffer. For large datasets this may lead to large memory footprint.
#   warnings.warn(*args, **kwargs)
# [metrics] saved metrics.json & psnr_curve.npy in out/img32_dense | controller=dense
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>K_train</td><td>▁▃▅▆█</td></tr><tr><td>beta</td><td>▁▃▅▆█</td></tr><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>eval/lpips_final</td><td>▁▄▆█▅</td></tr><tr><td>eval/psnr_final</td><td>█▄▂▁▃</td></tr><tr><td>eval/ssim_final</td><td>█▄▂▁▂</td></tr><tr><td>final/fid</td><td>▁</td></tr><tr><td>final/kid</td><td>▁</td></tr><tr><td>final/lpips</td><td>▁</td></tr><tr><td>final/psnr</td><td>▁</td></tr><tr><td>+4</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>K_train</td><td>9</td></tr><tr><td>beta</td><td>0.4</td></tr><tr><td>controller</td><td>dense</td></tr><tr><td>epoch</td><td>5</td></tr><tr><td>eval/lpips_final</td><td>0.08161</td></tr><tr><td>eval/psnr_final</td><td>17.1737</td></tr><tr><td>eval/ssim_final</td><td>0.39376</td></tr><tr><td>final/fid</td><td>175.35246</td></tr><tr><td>final/kid</td><td>0.17743</td></tr><tr><td>final/lpips</td><td>0.08161</td></tr><tr><td>+5</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">img32_ktrain10_keval20_epochs5_dense</strong> at: <a href='https://wandb.ai/stef4k-centralesup-lec/image_inpainting_notebook/runs/xjhikdc6' target="_blank">https://wandb.ai/stef4k-centralesup-lec/image_inpainting_notebook/runs/xjhikdc6</a><br> View project at: <a href='https://wandb.ai/stef4k-centralesup-lec/image_inpainting_notebook' target="_blank">https://wandb.ai/stef4k-centralesup-lec/image_inpainting_notebook</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251102_203219-xjhikdc6/logs</code>
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/drive/MyDrive/NFTM/wandb/run-20251102_204632-ill92ws1</code>
# Syncing run <strong><a href='https://wandb.ai/stef4k-centralesup-lec/image_inpainting_notebook/runs/ill92ws1' target="_blank">img32_ktrain10_keval20_epochs7_dense</a></strong> to <a href='https://wandb.ai/stef4k-centralesup-lec/image_inpainting_notebook' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/stef4k-centralesup-lec/image_inpainting_notebook' target="_blank">https://wandb.ai/stef4k-centralesup-lec/image_inpainting_notebook</a>
#  View run at <a href='https://wandb.ai/stef4k-centralesup-lec/image_inpainting_notebook/runs/ill92ws1' target="_blank">https://wandb.ai/stef4k-centralesup-lec/image_inpainting_notebook/runs/ill92ws1</a>
# === Running config: controller=dense, K_train=10, K_eval=20, epochs=7 ===
#
# [device] cuda | criterion=MSE
# [controller] dense | params=46375
# [ep 01] β_train=0.280 K_train=5 | loss 0.1257 | train PSNR 15.28 dB | eval PSNR 1..20: 14.98, 15.35, 15.69, 16.01, 16.31 ... 18.88 | ctrl=dense | final SSIM 0.5612 | final LPIPS 0.0615
# [ep 02] β_train=0.310 K_train=6 | loss 0.1353 | train PSNR 14.94 dB | eval PSNR 1..20: 14.79, 14.95, 15.09, 15.20, 15.29 ... 15.34 | ctrl=dense | final SSIM 0.3147 | final LPIPS 0.1635
# [ep 03] β_train=0.340 K_train=7 | loss 0.1263 | train PSNR 15.26 dB | eval PSNR 1..20: 14.97, 15.31, 15.61, 15.89, 16.13 ... 17.42 | ctrl=dense | final SSIM 0.4051 | final LPIPS 0.0823
# [ep 04] β_train=0.370 K_train=8 | loss 0.1222 | train PSNR 15.41 dB | eval PSNR 1..20: 14.98, 15.35, 15.67, 15.96, 16.22 ... 17.43 | ctrl=dense | final SSIM 0.4035 | final LPIPS 0.0782
# [ep 05] β_train=0.400 K_train=9 | loss 0.1197 | train PSNR 15.51 dB | eval PSNR 1..20: 15.04, 15.44, 15.81, 16.14, 16.43 ... 17.80 | ctrl=dense | final SSIM 0.4332 | final LPIPS 0.0696
# [ep 06] β_train=0.430 K_train=10 | loss 0.1163 | train PSNR 15.66 dB | eval PSNR 1..20: 15.07, 15.48, 15.86, 16.18, 16.47 ... 17.55 | ctrl=dense | final SSIM 0.4050 | final LPIPS 0.0751
# [ep 07] β_train=0.460 K_train=10 | loss 0.1133 | train PSNR 15.78 dB | eval PSNR 1..20: 15.11, 15.58, 16.01, 16.39, 16.73 ... 18.03 | ctrl=dense | final SSIM 0.4561 | final LPIPS 0.0624
# [plot] saved step-wise psnr (eval) → out/img32_dense/psnr_curve.png
# [plot] saved step-wise ssim (eval) → out/img32_dense/ssim_curve.png
# [plot] saved step-wise lpips (eval) → out/img32_dense/lpips_curve.png
# [viz] saved per-epoch progression → out/img32_dense/final/progress_epoch_final.png
# [gif] saved reconstruction GIF (GT top row, recon bottom) → out/img32_dense/final/progress_epoch_final.gif
# [done] checkpoints and plots saved under: out/img32_dense | controller=dense
# [metrics] saved metrics.json & psnr_curve.npy in out/img32_dense | controller=dense
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>K_train</td><td>▁▂▄▅▇██</td></tr><tr><td>beta</td><td>▁▂▃▄▆▇█</td></tr><tr><td>epoch</td><td>▁▂▃▅▆▇█</td></tr><tr><td>eval/lpips_final</td><td>▁█▂▂▂▂▁</td></tr><tr><td>eval/psnr_final</td><td>█▁▅▅▆▅▆</td></tr><tr><td>eval/ssim_final</td><td>█▁▄▄▄▄▅</td></tr><tr><td>final/fid</td><td>▁</td></tr><tr><td>final/kid</td><td>▁</td></tr><tr><td>final/lpips</td><td>▁</td></tr><tr><td>final/psnr</td><td>▁</td></tr><tr><td>+4</td><td>...</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>K_train</td><td>10</td></tr><tr><td>beta</td><td>0.46</td></tr><tr><td>controller</td><td>dense</td></tr><tr><td>epoch</td><td>7</td></tr><tr><td>eval/lpips_final</td><td>0.06241</td></tr><tr><td>eval/psnr_final</td><td>18.03161</td></tr><tr><td>eval/ssim_final</td><td>0.4561</td></tr><tr><td>final/fid</td><td>166.78365</td></tr><tr><td>final/kid</td><td>0.17104</td></tr><tr><td>final/lpips</td><td>0.06241</td></tr><tr><td>+5</td><td>...</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">img32_ktrain10_keval20_epochs7_dense</strong> at: <a href='https://wandb.ai/stef4k-centralesup-lec/image_inpainting_notebook/runs/ill92ws1' target="_blank">https://wandb.ai/stef4k-centralesup-lec/image_inpainting_notebook/runs/ill92ws1</a><br> View project at: <a href='https://wandb.ai/stef4k-centralesup-lec/image_inpainting_notebook' target="_blank">https://wandb.ai/stef4k-centralesup-lec/image_inpainting_notebook</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251102_204632-ill92ws1/logs</code>
